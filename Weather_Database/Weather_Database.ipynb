# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the time library
import time

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
city_data = []
set_count = 1
record_count = 1

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
     

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | lucea
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | katsuura
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | lebu
# Processing Record 8 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | kollam
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | kopavogur
# Processing Record 14 of Set 1 | ornskoldsvik
# Processing Record 15 of Set 1 | trinidad
# Processing Record 16 of Set 1 | padang
# Processing Record 17 of Set 1 | beringovskiy
# Processing Record 18 of Set 1 | oktyabrskiy
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | sao joao da barra
# Processing Record 21 of Set 1 | majholi
# Processing Record 22 of Set 1 | manggar
# Processing Record 23 of Set 1 | along
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | mayumba
# Processing Record 26 of Set 1 | yulara
# Processing Record 27 of Set 1 | villa carlos paz
# Processing Record 28 of Set 1 | vila velha
# Processing Record 29 of Set 1 | preston
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | rock springs
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | klaksvik
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | souillac
# Processing Record 36 of Set 1 | gizo
# Processing Record 37 of Set 1 | bara
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | boli
# Processing Record 40 of Set 1 | bilma
# Processing Record 41 of Set 1 | ondjiva
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 1 | khatanga
# Processing Record 47 of Set 1 | rikitea
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 1 | ojinaga
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | boca do acre
# Processing Record 3 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 2 | bengkulu
# Processing Record 5 of Set 2 | upernavik
# Processing Record 6 of Set 2 | salalah
# Processing Record 7 of Set 2 | cidreira
# Processing Record 8 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | kavieng
# Processing Record 12 of Set 2 | abu samrah
# Processing Record 13 of Set 2 | chuy
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | lasa
# Processing Record 16 of Set 2 | jacqueville
# Processing Record 17 of Set 2 | constitucion
# Processing Record 18 of Set 2 | nyurba
# Processing Record 19 of Set 2 | praia da vitoria
# Processing Record 20 of Set 2 | bathsheba
# Processing Record 21 of Set 2 | karratha
# Processing Record 22 of Set 2 | sorland
# Processing Record 23 of Set 2 | coihaique
# Processing Record 24 of Set 2 | fare
# Processing Record 25 of Set 2 | paita
# Processing Record 26 of Set 2 | alpena
# Processing Record 27 of Set 2 | altamira
# Processing Record 28 of Set 2 | hakkari
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | fairbanks
# Processing Record 31 of Set 2 | paralimni
# Processing Record 32 of Set 2 | lompoc
# Processing Record 33 of Set 2 | puerto ayora
# Processing Record 34 of Set 2 | kalmunai
# Processing Record 35 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 2 | pangnirtung
# Processing Record 37 of Set 2 | porbandar
# Processing Record 38 of Set 2 | kyshtovka
# Processing Record 39 of Set 2 | newark
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | albany
# Processing Record 42 of Set 2 | saint-philippe
# Processing Record 43 of Set 2 | zheleznodorozhnyy
# Processing Record 44 of Set 2 | atuona
# Processing Record 45 of Set 2 | thinadhoo
# Processing Record 46 of Set 2 | bambous virieux
# Processing Record 47 of Set 2 | oskaloosa
# Processing Record 48 of Set 2 | mar del plata
# Processing Record 49 of Set 2 | sao filipe
# Processing Record 50 of Set 2 | sitka
# Processing Record 1 of Set 3 | taoudenni
# Processing Record 2 of Set 3 | barrow
# Processing Record 3 of Set 3 | boa viagem
# Processing Record 4 of Set 3 | awjilah
# Processing Record 5 of Set 3 | inhambane
# Processing Record 6 of Set 3 | esperance
# Processing Record 7 of Set 3 | monrovia
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | kodiak
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | north bend
# Processing Record 12 of Set 3 | chama
# Processing Record 13 of Set 3 | ixtapa
# Processing Record 14 of Set 3 | srednekolymsk
# Processing Record 15 of Set 3 | maneadero
# Processing Record 16 of Set 3 | laguna
# Processing Record 17 of Set 3 | waitara
# Processing Record 18 of Set 3 | ormara
# Processing Record 19 of Set 3 | pingliang
# Processing Record 20 of Set 3 | oranjemund
# Processing Record 21 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 3 | canmore
# Processing Record 23 of Set 3 | novoagansk
# Processing Record 24 of Set 3 | hundested
# Processing Record 25 of Set 3 | lavrentiya
# Processing Record 26 of Set 3 | poum
# Processing Record 27 of Set 3 | ayolas
# Processing Record 28 of Set 3 | comodoro rivadavia
# Processing Record 29 of Set 3 | pauini
# Processing Record 30 of Set 3 | provideniya
# Processing Record 31 of Set 3 | fukue
# Processing Record 32 of Set 3 | hamilton
# Processing Record 33 of Set 3 | sinnamary
# Processing Record 34 of Set 3 | safaga
# Processing Record 35 of Set 3 | lorengau
# Processing Record 36 of Set 3 | port macquarie
# Processing Record 37 of Set 3 | yellowknife
# Processing Record 38 of Set 3 | phayao
# Processing Record 39 of Set 3 | dunedin
# Processing Record 40 of Set 3 | saskylakh
# Processing Record 41 of Set 3 | pevek
# Processing Record 42 of Set 3 | vung tau
# Processing Record 43 of Set 3 | kikwit
# Processing Record 44 of Set 3 | touros
# Processing Record 45 of Set 3 | port elizabeth
# Processing Record 46 of Set 3 | duncan
# Processing Record 47 of Set 3 | taltal
# Processing Record 48 of Set 3 | pochutla
# Processing Record 49 of Set 3 | lalmohan
# Processing Record 50 of Set 3 | ponta do sol
# Processing Record 1 of Set 4 | rincon
# Processing Record 2 of Set 4 | vardo
# Processing Record 3 of Set 4 | braunau
# Processing Record 4 of Set 4 | san juan
# Processing Record 5 of Set 4 | palembang
# Processing Record 6 of Set 4 | baykit
# Processing Record 7 of Set 4 | bredasdorp
# Processing Record 8 of Set 4 | magadi
# Processing Record 9 of Set 4 | leninskoye
# Processing Record 10 of Set 4 | shu
# Processing Record 11 of Set 4 | san patricio
# Processing Record 12 of Set 4 | sorong
# Processing Record 13 of Set 4 | leningradskiy
# Processing Record 14 of Set 4 | torbay
# Processing Record 15 of Set 4 | auki
# Processing Record 16 of Set 4 | chokurdakh
# Processing Record 17 of Set 4 | solnechnyy
# Processing Record 18 of Set 4 | maxixe
# Processing Record 19 of Set 4 | porto empedocle
# Processing Record 20 of Set 4 | kaitangata
# Processing Record 21 of Set 4 | ancud
# Processing Record 22 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 23 of Set 4 | tuatapere
# Processing Record 24 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 4 | otradnyy
# Processing Record 26 of Set 4 | chapais
# Processing Record 27 of Set 4 | bonavista
# Processing Record 28 of Set 4 | segovia
# Processing Record 29 of Set 4 | broken hill
# Processing Record 30 of Set 4 | qaanaaq
# Processing Record 31 of Set 4 | tiksi
# Processing Record 32 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 4 | wewak
# Processing Record 34 of Set 4 | skibbereen
# Processing Record 35 of Set 4 | borujan
# City not found. Skipping...
# Processing Record 36 of Set 4 | birao
# Processing Record 37 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 4 | tasiilaq
# Processing Record 39 of Set 4 | vostok
# Processing Record 40 of Set 4 | bochum
# Processing Record 41 of Set 4 | airai
# Processing Record 42 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 4 | jijiga
# Processing Record 44 of Set 4 | norman wells
# Processing Record 45 of Set 4 | rundu
# Processing Record 46 of Set 4 | coahuayana
# Processing Record 47 of Set 4 | celestun
# Processing Record 48 of Set 4 | vestmannaeyjar
# Processing Record 49 of Set 4 | qovlar
# Processing Record 50 of Set 4 | tautira
# Processing Record 1 of Set 5 | luderitz
# Processing Record 2 of Set 5 | trairi
# Processing Record 3 of Set 5 | shieli
# Processing Record 4 of Set 5 | san policarpo
# Processing Record 5 of Set 5 | hyeres
# Processing Record 6 of Set 5 | barra do garcas
# Processing Record 7 of Set 5 | tilichiki
# Processing Record 8 of Set 5 | yerbogachen
# Processing Record 9 of Set 5 | hakui
# Processing Record 10 of Set 5 | araouane
# Processing Record 11 of Set 5 | new norfolk
# Processing Record 12 of Set 5 | hermanus
# Processing Record 13 of Set 5 | paso de los toros
# Processing Record 14 of Set 5 | kombissiri
# Processing Record 15 of Set 5 | camacha
# Processing Record 16 of Set 5 | port hardy
# Processing Record 17 of Set 5 | linqiong
# Processing Record 18 of Set 5 | saldanha
# Processing Record 19 of Set 5 | energeticheskiy
# Processing Record 20 of Set 5 | assiniboia
# Processing Record 21 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 5 | khairpur
# Processing Record 23 of Set 5 | golden
# Processing Record 24 of Set 5 | victoria
# Processing Record 25 of Set 5 | nioro
# Processing Record 26 of Set 5 | severo-kurilsk
# Processing Record 27 of Set 5 | biloela
# Processing Record 28 of Set 5 | arraial do cabo
# Processing Record 29 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 30 of Set 5 | cherskiy
# Processing Record 31 of Set 5 | tuktoyaktuk
# Processing Record 32 of Set 5 | wattegama
# Processing Record 33 of Set 5 | brodnica
# Processing Record 34 of Set 5 | kaihua
# Processing Record 35 of Set 5 | zambezi
# Processing Record 36 of Set 5 | russell
# Processing Record 37 of Set 5 | port shepstone
# Processing Record 38 of Set 5 | thompson
# Processing Record 39 of Set 5 | tagusao
# Processing Record 40 of Set 5 | saint george
# Processing Record 41 of Set 5 | itarema
# Processing Record 42 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 5 | castro
# Processing Record 44 of Set 5 | road town
# Processing Record 45 of Set 5 | azul
# Processing Record 46 of Set 5 | coquimbo
# Processing Record 47 of Set 5 | tukrah
# Processing Record 48 of Set 5 | waipawa
# Processing Record 49 of Set 5 | tahoua
# Processing Record 50 of Set 5 | gorontalo
# Processing Record 1 of Set 6 | berlevag
# Processing Record 2 of Set 6 | cam pha
# City not found. Skipping...
# Processing Record 3 of Set 6 | bonthe
# Processing Record 4 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 5 of Set 6 | barao de melgaco
# Processing Record 6 of Set 6 | hithadhoo
# Processing Record 7 of Set 6 | tombouctou
# Processing Record 8 of Set 6 | adrar
# Processing Record 9 of Set 6 | pemba
# Processing Record 10 of Set 6 | sovetskiy
# Processing Record 11 of Set 6 | san joaquin
# Processing Record 12 of Set 6 | naze
# Processing Record 13 of Set 6 | bambanglipuro
# Processing Record 14 of Set 6 | henties bay
# Processing Record 15 of Set 6 | bubaque
# Processing Record 16 of Set 6 | vysokogornyy
# Processing Record 17 of Set 6 | broken arrow
# Processing Record 18 of Set 6 | dangriga
# Processing Record 19 of Set 6 | yamada
# Processing Record 20 of Set 6 | wakkanai
# Processing Record 21 of Set 6 | karpogory
# Processing Record 22 of Set 6 | talnakh
# Processing Record 23 of Set 6 | panguna
# Processing Record 24 of Set 6 | khani
# Processing Record 25 of Set 6 | faanui
# Processing Record 26 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 6 | iqaluit
# Processing Record 28 of Set 6 | kristiansund
# Processing Record 29 of Set 6 | berdigestyakh
# Processing Record 30 of Set 6 | alta floresta
# Processing Record 31 of Set 6 | palauig
# Processing Record 32 of Set 6 | aklavik
# Processing Record 33 of Set 6 | rudbar
# Processing Record 34 of Set 6 | neijiang
# Processing Record 35 of Set 6 | nurota
# Processing Record 36 of Set 6 | lata
# Processing Record 37 of Set 6 | moron
# Processing Record 38 of Set 6 | panaba
# Processing Record 39 of Set 6 | hays
# Processing Record 40 of Set 6 | cairns
# Processing Record 41 of Set 6 | saint-pierre
# Processing Record 42 of Set 6 | kamennomostskiy
# Processing Record 43 of Set 6 | ambon
# Processing Record 44 of Set 6 | muscat
# Processing Record 45 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 6 | finschhafen
# Processing Record 47 of Set 6 | te anau
# Processing Record 48 of Set 6 | urumqi
# Processing Record 49 of Set 6 | college
# Processing Record 50 of Set 6 | francistown
# Processing Record 1 of Set 7 | aksay
# Processing Record 2 of Set 7 | kiunga
# Processing Record 3 of Set 7 | buckeye
# Processing Record 4 of Set 7 | lagoa
# Processing Record 5 of Set 7 | asosa
# Processing Record 6 of Set 7 | vysokopillya
# Processing Record 7 of Set 7 | pimentel
# Processing Record 8 of Set 7 | bullhead city
# Processing Record 9 of Set 7 | meulaboh
# Processing Record 10 of Set 7 | baijiantan
# Processing Record 11 of Set 7 | guerrero negro
# Processing Record 12 of Set 7 | tshikapa
# Processing Record 13 of Set 7 | mogzon
# Processing Record 14 of Set 7 | cockburn town
# Processing Record 15 of Set 7 | lucapa
# Processing Record 16 of Set 7 | marawi
# Processing Record 17 of Set 7 | price
# Processing Record 18 of Set 7 | viking
# Processing Record 19 of Set 7 | sola
# Processing Record 20 of Set 7 | geraldton
# Processing Record 21 of Set 7 | vieux-habitants
# Processing Record 22 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 23 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 24 of Set 7 | kudahuvadhoo
# Processing Record 25 of Set 7 | coari
# Processing Record 26 of Set 7 | kourou
# Processing Record 27 of Set 7 | mercedes
# Processing Record 28 of Set 7 | paoua
# Processing Record 29 of Set 7 | husavik
# Processing Record 30 of Set 7 | carnarvon
# Processing Record 31 of Set 7 | takoradi
# Processing Record 32 of Set 7 | dauriya
# Processing Record 33 of Set 7 | batagay-alyta
# Processing Record 34 of Set 7 | gangotri
# City not found. Skipping...
# Processing Record 35 of Set 7 | komsomolskiy
# Processing Record 36 of Set 7 | ola
# Processing Record 37 of Set 7 | olafsvik
# Processing Record 38 of Set 7 | xinmin
# Processing Record 39 of Set 7 | bardiyah
# Processing Record 40 of Set 7 | virginia beach
# Processing Record 41 of Set 7 | kibondo
# Processing Record 42 of Set 7 | okhotsk
# Processing Record 43 of Set 7 | narok
# Processing Record 44 of Set 7 | valparaiso
# Processing Record 45 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 7 | faya
# Processing Record 48 of Set 7 | chiredzi
# Processing Record 49 of Set 7 | ulladulla
# Processing Record 50 of Set 7 | panzhihua
# Processing Record 1 of Set 8 | linguere
# Processing Record 2 of Set 8 | tura
# Processing Record 3 of Set 8 | port augusta
# Processing Record 4 of Set 8 | machaneng
# Processing Record 5 of Set 8 | andenes
# Processing Record 6 of Set 8 | kavaratti
# Processing Record 7 of Set 8 | villa del rosario
# Processing Record 8 of Set 8 | kruisfontein
# Processing Record 9 of Set 8 | banamba
# Processing Record 10 of Set 8 | belmonte
# Processing Record 11 of Set 8 | millerovo
# Processing Record 12 of Set 8 | vao
# Processing Record 13 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 14 of Set 8 | kozhva
# Processing Record 15 of Set 8 | buala
# Processing Record 16 of Set 8 | tunduma
# Processing Record 17 of Set 8 | alofi
# Processing Record 18 of Set 8 | gidole
# Processing Record 19 of Set 8 | zhanaozen
# Processing Record 20 of Set 8 | almeria
# Processing Record 21 of Set 8 | deputatskiy
# Processing Record 22 of Set 8 | nabire
# Processing Record 23 of Set 8 | nara
# Processing Record 24 of Set 8 | ilulissat
# Processing Record 25 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 27 of Set 8 | ilula
# Processing Record 28 of Set 8 | asfi
# Processing Record 29 of Set 8 | sohag
# Processing Record 30 of Set 8 | churapcha
# Processing Record 31 of Set 8 | atar
# Processing Record 32 of Set 8 | nam tha
# City not found. Skipping...
# Processing Record 33 of Set 8 | krasnyy yar
# Processing Record 34 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 8 | atherton
# Processing Record 36 of Set 8 | uchaly
# Processing Record 37 of Set 8 | falkoping
# City not found. Skipping...
# Processing Record 38 of Set 8 | walla walla
# Processing Record 39 of Set 8 | sassandra
# Processing Record 40 of Set 8 | holstebro
# Processing Record 41 of Set 8 | lakatoro
# Processing Record 42 of Set 8 | kahului
# Processing Record 43 of Set 8 | nagireddipalle
# City not found. Skipping...
# Processing Record 44 of Set 8 | sechura
# Processing Record 45 of Set 8 | west wendover
# Processing Record 46 of Set 8 | ambunti
# Processing Record 47 of Set 8 | hasaki
# Processing Record 48 of Set 8 | fortuna
# Processing Record 49 of Set 8 | mezhova
# Processing Record 50 of Set 8 | tabatinga
# Processing Record 1 of Set 9 | bobo dioulasso
# Processing Record 2 of Set 9 | sao felix do xingu
# Processing Record 3 of Set 9 | narsaq
# Processing Record 4 of Set 9 | aswan
# Processing Record 5 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 6 of Set 9 | ossora
# Processing Record 7 of Set 9 | kimbe
# Processing Record 8 of Set 9 | puerto del rosario
# Processing Record 9 of Set 9 | sibinal
# Processing Record 10 of Set 9 | quimperle
# Processing Record 11 of Set 9 | namie
# Processing Record 12 of Set 9 | manakara
# Processing Record 13 of Set 9 | januaria
# Processing Record 14 of Set 9 | whyalla
# Processing Record 15 of Set 9 | urucara
# Processing Record 16 of Set 9 | luganville
# Processing Record 17 of Set 9 | plouzane
# Processing Record 18 of Set 9 | pucara
# Processing Record 19 of Set 9 | peace river
# Processing Record 20 of Set 9 | abong mbang
# Processing Record 21 of Set 9 | saint quentin
# City not found. Skipping...
# Processing Record 22 of Set 9 | catuday
# Processing Record 23 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 9 | ewa beach
# Processing Record 26 of Set 9 | nyrob
# Processing Record 27 of Set 9 | manicore
# Processing Record 28 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 9 | kathu
# Processing Record 30 of Set 9 | nanakuli
# Processing Record 31 of Set 9 | mount gambier
# Processing Record 32 of Set 9 | bagan
# Processing Record 33 of Set 9 | imbituba
# Processing Record 34 of Set 9 | saint-augustin
# Processing Record 35 of Set 9 | doha
# Processing Record 36 of Set 9 | salinopolis
# Processing Record 37 of Set 9 | maningrida
# Processing Record 38 of Set 9 | half moon bay
# Processing Record 39 of Set 9 | maldonado
# Processing Record 40 of Set 9 | turukhansk
# Processing Record 41 of Set 9 | baghdad
# Processing Record 42 of Set 9 | nemuro
# Processing Record 43 of Set 9 | kutum
# Processing Record 44 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 9 | porto seguro
# Processing Record 46 of Set 9 | doctor arroyo
# Processing Record 47 of Set 9 | algeciras
# Processing Record 48 of Set 9 | krasnoarmeysk
# Processing Record 49 of Set 9 | conchagua
# Processing Record 50 of Set 9 | cody
# Processing Record 1 of Set 10 | san borja
# Processing Record 2 of Set 10 | abonnema
# Processing Record 3 of Set 10 | coihueco
# Processing Record 4 of Set 10 | maragogi
# Processing Record 5 of Set 10 | corner brook
# Processing Record 6 of Set 10 | bhojudih
# Processing Record 7 of Set 10 | vanavara
# Processing Record 8 of Set 10 | kirkwall
# Processing Record 9 of Set 10 | kirensk
# Processing Record 10 of Set 10 | kawalu
# Processing Record 11 of Set 10 | dwarka
# Processing Record 12 of Set 10 | bilibino
# Processing Record 13 of Set 10 | san quintin
# Processing Record 14 of Set 10 | makubetsu
# Processing Record 15 of Set 10 | dingle
# Processing Record 16 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 10 | saint-francois
# Processing Record 18 of Set 10 | wilmington
# Processing Record 19 of Set 10 | el alto
# Processing Record 20 of Set 10 | belaya gora
# Processing Record 21 of Set 10 | puri
# Processing Record 22 of Set 10 | la uribe
# City not found. Skipping...
# Processing Record 23 of Set 10 | baturaja
# Processing Record 24 of Set 10 | ketchikan
# Processing Record 25 of Set 10 | ifanadiana
# Processing Record 26 of Set 10 | nalobikha
# Processing Record 27 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 10 | koroni
# Processing Record 29 of Set 10 | paris
# Processing Record 30 of Set 10 | cayenne
# Processing Record 31 of Set 10 | sao miguel do araguaia
# Processing Record 32 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 10 | harindanga
# Processing Record 34 of Set 10 | portland
# Processing Record 35 of Set 10 | sergeyevka
# Processing Record 36 of Set 10 | bandundu
# Processing Record 37 of Set 10 | west bay
# Processing Record 38 of Set 10 | christchurch
# Processing Record 39 of Set 10 | southampton
# Processing Record 40 of Set 10 | nogales
# Processing Record 41 of Set 10 | korla
# Processing Record 42 of Set 10 | santiago de las vegas
# Processing Record 43 of Set 10 | pangody
# Processing Record 44 of Set 10 | okha
# Processing Record 45 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 10 | pincher creek
# Processing Record 47 of Set 10 | nanortalik
# Processing Record 48 of Set 10 | ahipara
# Processing Record 49 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 10 | marathon
# Processing Record 1 of Set 11 | port lincoln
# Processing Record 2 of Set 11 | shelburne
# Processing Record 3 of Set 11 | nam som
# Processing Record 4 of Set 11 | solton
# Processing Record 5 of Set 11 | la ronge
# Processing Record 6 of Set 11 | longyearbyen
# Processing Record 7 of Set 11 | tieling
# Processing Record 8 of Set 11 | valley city
# Processing Record 9 of Set 11 | otaru
# Processing Record 10 of Set 11 | aksarka
# Processing Record 11 of Set 11 | mecca
# Processing Record 12 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 11 | santa rosa
# Processing Record 14 of Set 11 | wakefield
# Processing Record 15 of Set 11 | yueyang
# Processing Record 16 of Set 11 | puerto rondon
# Processing Record 17 of Set 11 | seminole
# Processing Record 18 of Set 11 | antofagasta
# Processing Record 19 of Set 11 | bud
# Processing Record 20 of Set 11 | waterloo
# Processing Record 21 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 22 of Set 11 | venado tuerto
# Processing Record 23 of Set 11 | kenai
# Processing Record 24 of Set 11 | batangafo
# Processing Record 25 of Set 11 | skjervoy
# Processing Record 26 of Set 11 | ambagarh chauki
# Processing Record 27 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 28 of Set 11 | sayyan
# Processing Record 29 of Set 11 | marseille
# Processing Record 30 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 31 of Set 11 | frederick
# Processing Record 32 of Set 11 | shiyan
# Processing Record 33 of Set 11 | ulcinj
# Processing Record 34 of Set 11 | konstantinovka
# Processing Record 35 of Set 11 | bayonet point
# Processing Record 36 of Set 11 | torrington
# Processing Record 37 of Set 11 | mount isa
# Processing Record 38 of Set 11 | yeppoon
# Processing Record 39 of Set 11 | kununurra
# Processing Record 40 of Set 11 | tayga
# Processing Record 41 of Set 11 | gunjur
# Processing Record 42 of Set 11 | codrington
# Processing Record 43 of Set 11 | gafanha da encarnacao
# Processing Record 44 of Set 11 | grand gaube
# Processing Record 45 of Set 11 | ust-tsilma
# Processing Record 46 of Set 11 | sobolevo
# Processing Record 47 of Set 11 | inuvik
# Processing Record 48 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 11 | fuling
# Processing Record 50 of Set 11 | bahar
# Processing Record 1 of Set 12 | dzerzhinsk
# Processing Record 2 of Set 12 | kazachinskoye
# Processing Record 3 of Set 12 | middelburg
# Processing Record 4 of Set 12 | toora-khem
# Processing Record 5 of Set 12 | hammerfest
# Processing Record 6 of Set 12 | qasigiannguit
# Processing Record 7 of Set 12 | nowy dwor gdanski
# Processing Record 8 of Set 12 | magdagachi
# Processing Record 9 of Set 12 | tezu
# Processing Record 10 of Set 12 | qui nhon
# Processing Record 11 of Set 12 | havelock
# Processing Record 12 of Set 12 | omboue
# Processing Record 13 of Set 12 | cascais
# Processing Record 14 of Set 12 | birjand
# Processing Record 15 of Set 12 | richards bay
# Processing Record 16 of Set 12 | pedernales
# Processing Record 17 of Set 12 | sharan
# Processing Record 18 of Set 12 | orbetello
# Processing Record 19 of Set 12 | frankenberg
# Processing Record 20 of Set 12 | bowen
# Processing Record 21 of Set 12 | tomatlan
# Processing Record 22 of Set 12 | sirjan
# Processing Record 23 of Set 12 | kamuli
# Processing Record 24 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 12 | clyde river
# Processing Record 26 of Set 12 | saint-georges
# Processing Record 27 of Set 12 | araguacu
# Processing Record 28 of Set 12 | hervey bay
# Processing Record 29 of Set 12 | umm lajj
# Processing Record 30 of Set 12 | bagdarin
# Processing Record 31 of Set 12 | mantua
# Processing Record 32 of Set 12 | dohrighat
# Processing Record 33 of Set 12 | los llanos de aridane
# Processing Record 34 of Set 12 | misratah
# Processing Record 35 of Set 12 | praia
# Processing Record 36 of Set 12 | port hedland
# Processing Record 37 of Set 12 | awbari
# Processing Record 38 of Set 12 | rognan
# Processing Record 39 of Set 12 | miragoane
# Processing Record 40 of Set 12 | wufeng
# Processing Record 41 of Set 12 | goundam
# Processing Record 42 of Set 12 | dandong
# Processing Record 43 of Set 12 | mwanza
# Processing Record 44 of Set 12 | semikarakorsk
# Processing Record 45 of Set 12 | tecoanapa
# Processing Record 46 of Set 12 | bellavista
# Processing Record 47 of Set 12 | rongcheng
# Processing Record 48 of Set 12 | pokhara
# Processing Record 49 of Set 12 | puerto escondido
# Processing Record 50 of Set 12 | krutaya gorka
# Processing Record 1 of Set 13 | suntar
# Processing Record 2 of Set 13 | alice springs
# Processing Record 3 of Set 13 | isangel
# Processing Record 4 of Set 13 | hirara
# Processing Record 5 of Set 13 | la chapelle-sur-erdre
# Processing Record 6 of Set 13 | tondano
# Processing Record 7 of Set 13 | la rioja
# Processing Record 8 of Set 13 | muisne
# Processing Record 9 of Set 13 | mokhotlong
# Processing Record 10 of Set 13 | ikungi
# Processing Record 11 of Set 13 | lebowakgomo
# Processing Record 12 of Set 13 | bull savanna
# Processing Record 13 of Set 13 | tocopilla
# Processing Record 14 of Set 13 | nome
# Processing Record 15 of Set 13 | port hawkesbury
# Processing Record 16 of Set 13 | san francisco
# Processing Record 17 of Set 13 | changji
# Processing Record 18 of Set 13 | guadix
# Processing Record 19 of Set 13 | hargeysa
# Processing Record 20 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 13 | labuan
# Processing Record 22 of Set 13 | yelizovo
# Processing Record 23 of Set 13 | gavle
# Processing Record 24 of Set 13 | teguldet
# Processing Record 25 of Set 13 | sanmenxia
# Processing Record 26 of Set 13 | kitimat
# Processing Record 27 of Set 13 | lima
# Processing Record 28 of Set 13 | walvis bay
# Processing Record 29 of Set 13 | naples
# Processing Record 30 of Set 13 | guanay
# Processing Record 31 of Set 13 | kokoda
# Processing Record 32 of Set 13 | augusta
# Processing Record 33 of Set 13 | mujiayingzi
# Processing Record 34 of Set 13 | kyren
# Processing Record 35 of Set 13 | vila
# Processing Record 36 of Set 13 | biscarrosse
# Processing Record 37 of Set 13 | calama
# Processing Record 38 of Set 13 | sokone
# Processing Record 39 of Set 13 | strezhevoy
# Processing Record 40 of Set 13 | oranjestad
# Processing Record 41 of Set 13 | nalut
# Processing Record 42 of Set 13 | batemans bay
# Processing Record 43 of Set 13 | iquique
# Processing Record 44 of Set 13 | zavodoukovsk
# Processing Record 45 of Set 13 | zhigansk
# Processing Record 46 of Set 13 | samarai
# Processing Record 47 of Set 13 | aripuana
# Processing Record 48 of Set 13 | kuhdasht
# Processing Record 49 of Set 13 | hambantota
# Processing Record 50 of Set 13 | raudeberg
# Processing Record 1 of Set 14 | mawlaik
# Processing Record 2 of Set 14 | millinocket
# Processing Record 3 of Set 14 | ulaanbaatar
# Processing Record 4 of Set 14 | meridian
# Processing Record 5 of Set 14 | lukovetskiy
# Processing Record 6 of Set 14 | aktau
# Processing Record 7 of Set 14 | beloha
# Processing Record 8 of Set 14 | abha
# Processing Record 9 of Set 14 | erdaojiang
# Processing Record 10 of Set 14 | waw
# Processing Record 11 of Set 14 | tessalit
# Processing Record 12 of Set 14 | borovichi
# Processing Record 13 of Set 14 | almaznyy
# Processing Record 14 of Set 14 | lodja
# Processing Record 15 of Set 14 | mangai
# Processing Record 16 of Set 14 | flinders
# Processing Record 17 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 18 of Set 14 | chiriqui grande
# Processing Record 19 of Set 14 | parabel
# Processing Record 20 of Set 14 | haysyn
# Processing Record 21 of Set 14 | gewane
# Processing Record 22 of Set 14 | turayf
# Processing Record 23 of Set 14 | mahendranagar
# Processing Record 24 of Set 14 | koungou
# Processing Record 25 of Set 14 | naron
# Processing Record 26 of Set 14 | xuddur
# Processing Record 27 of Set 14 | lubbock
# Processing Record 28 of Set 14 | ambilobe
# Processing Record 29 of Set 14 | qeshm
# Processing Record 30 of Set 14 | coventry
# Processing Record 31 of Set 14 | agirish
# Processing Record 32 of Set 14 | sisimiut
# Processing Record 33 of Set 14 | skelleftea
# Processing Record 34 of Set 14 | salekhard
# Processing Record 35 of Set 14 | banda aceh
# Processing Record 36 of Set 14 | mareeba
# Processing Record 37 of Set 14 | peniche
# Processing Record 38 of Set 14 | victor harbor
# Processing Record 39 of Set 14 | tortosa
# Processing Record 40 of Set 14 | subirana
# Processing Record 41 of Set 14 | luzhou
# Processing Record 42 of Set 14 | kiama
# Processing Record 43 of Set 14 | ciudad bolivar
# Processing Record 44 of Set 14 | manama
# Processing Record 45 of Set 14 | bandarbeyla
# Processing Record 46 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 14 | adet
# Processing Record 48 of Set 14 | andros town
# Processing Record 49 of Set 14 | semnan
# Processing Record 50 of Set 14 | severobaykalsk
# Processing Record 1 of Set 15 | sekovici
# Processing Record 2 of Set 15 | pemangkat
# Processing Record 3 of Set 15 | denpasar
# Processing Record 4 of Set 15 | raton
# Processing Record 5 of Set 15 | waitati
# Processing Record 6 of Set 15 | ban nahin
# Processing Record 7 of Set 15 | tawau
# Processing Record 8 of Set 15 | moussoro
# Processing Record 9 of Set 15 | sung noen
# Processing Record 10 of Set 15 | high level
# Processing Record 11 of Set 15 | kabinda
# Processing Record 12 of Set 15 | grindavik
# Processing Record 13 of Set 15 | bitung
# Processing Record 14 of Set 15 | bo rai
# Processing Record 15 of Set 15 | lapi
# Processing Record 16 of Set 15 | puteyets
# Processing Record 17 of Set 15 | launceston
# Processing Record 18 of Set 15 | palmer
# Processing Record 19 of Set 15 | ishinomaki
# Processing Record 20 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 21 of Set 15 | egvekinot
# Processing Record 22 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 23 of Set 15 | sabang
# Processing Record 24 of Set 15 | rio gallegos
# Processing Record 25 of Set 15 | prince rupert
# Processing Record 26 of Set 15 | josanicka banja
# Processing Record 27 of Set 15 | batagay
# Processing Record 28 of Set 15 | dumas
# Processing Record 29 of Set 15 | zhigalovo
# Processing Record 30 of Set 15 | saint anthony
# Processing Record 31 of Set 15 | zarate
# Processing Record 32 of Set 15 | beaufort
# Processing Record 33 of Set 15 | hukuntsi
# Processing Record 34 of Set 15 | balabac
# Processing Record 35 of Set 15 | arenapolis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data).style.format({
    "Lat": "{:.2f}",
    "Lng": "{:.2f}",
    "Max Temp": "{:.2f}",
    "Wind Speed": "{:.2f}"
})

# %%
city_data_df = city_data_df.data

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
